# %%
# Program to perform Sentiment Analysis on Twitter dataset to classify the tweets into depressed and not depressed.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing the dataset
tweets = pd.read_csv("sentiment_tweets3.csv")
tweets.head()
# Out:
#    Unnamed: 0                                            message  label
# 0         106  just had a real good moment. i missssssssss hi...      0
# 1         217         is reading manga  http://plurk.com/p/mzp1e      0
# 2         220  @comeagainjen http://twitpic.com/2y2lx - http:...      0
# 3         288  @lapcat Need to send 'em to my accountant tomo...      0
# 4         540      ADD ME ON MYSPACE!!!  myspace.com/LookThunder      0

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10314 entries, 0 to 10313
# Data columns (total 3 columns):
# Unnamed: 0    10314 non-null int64
# message       10314 non-null object
# label         10314 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 241.8+ KB

# %%
#dropping the unnamed column
#axis 0 = rows axis 1 = column
tweets= tweets.drop("Unnamed: 0",axis=1)

# %%
tweets.head()
# Out:
#                                              message  label
# 0  just had a real good moment. i missssssssss hi...      0
# 1         is reading manga  http://plurk.com/p/mzp1e      0
# 2  @comeagainjen http://twitpic.com/2y2lx - http:...      0
# 3  @lapcat Need to send 'em to my accountant tomo...      0
# 4      ADD ME ON MYSPACE!!!  myspace.com/LookThunder      0

# %%
#get the total counts of the labels
tweets["label"].value_counts()
# Out:
# 0    8000
# 1    2314
# Name: label, dtype: int64

# %%
#visually seeing the distribution of data in different classes
# %matplotlib inline

from collections import Counter
target_cnt = Counter(tweets.label)

plt.bar(target_cnt.keys(), target_cnt.values())
plt.title("Dataset class distribution")
# Out:
# Text(0.5, 1.0, 'Dataset class distribution')

# %%
#creating a function to clean the free text using n-grams, stop word removal and stemming

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

def clean_message(message, lower_case = True, stem = True, stop_words = True, gram = 1):
    if lower_case:
        message = message.lower()
    words = word_tokenize(message)
    words = [w for w in words if len(w) > 2]
    if gram > 1:
        w = []
        for i in range(len(words) - gram + 1):
            w += [' '.join(words[i:i + gram])]
        return ' '.join(words)
    if stop_words:
        sw = stopwords.words('english')
        words = [word for word in words if word not in sw]
    if stem:
        stemmer = PorterStemmer()
        words = [stemmer.stem(word) for word in words]   
    sentence = ' '.join(words)
    return sentence
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fbazil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#clean the messages and save in a new column
tweets['clean_message'] = tweets['message'].apply(lambda x: clean_message(x))

tweets['clean_message']
# Out:
# 0                       real good moment missssssssss much
# 1                       read manga http //plurk.com/p/mzp1
# 2        comeagainjen http //twitpic.com/2y2lx http //w...
# 3        lapcat need send 'em account tomorrow oddli n'...
# 4                         add myspac myspace.com/lookthund
# 5                          sleepi good time tonight though
# 6        silkcharm nbn someon alreadi said fiber home m...
# 7                                24ï¿½c possibl today nice
# 8                            nite twittervil workout -ciao
# 9                          danann night darlin sweet dream
# 10                                     good morn everybodi
# 11       final creat wordpress blog alreadi blog seattl...
# 12                    kisha cnt get til get frm rememb top
# 13           nicolerichi ye rememb band awesom pleas repli
# 14                              realli love reflect shadow
# 15           blueaero ooo fantasi like fantasi novel check
# 16       rokchic28 prob sell noth blog http //snedwan.c...
# 17                shipovalov quot nokla connect peopl quot
# 18               stay late start earli good thing like job
# 19                 kal_penn read new job congratul fantast
# 20          n't abl sleep think 'll watch ugli betti onlin
# 21       woo thank ron steev follow yeow folowerssss ha...
# 22              aidenchan yeah sure sister take extra care
# 23        sian_the_mous yay duck want anyth watch duck lol
# 24       smaaack ass hahhahahaa make laugh oooooh sleee...
# 25                woo late haha goodnight twittervers xoxo
# 26                     look forward meet pastor kong later
# 27       doubleickey know minichocol shape liquor bottl...
# 28                     test see twitter work thro facebook
# 29       night babi got vh1 thing check pic http //twit...
#                                ...
# 10284    sometim n't fit friend alway verg give guy gav...
# 10285    depress feel like cri everi time someon ask fe...
# 10286    girlllll type depress swear pain physic aint n...
# 10287    girl made season deal mental ill depress ptsd ...
# 10288    suddenli good feel ok.bmp jpeg would high qual...
# 10289    yoga old age yoga weak stress depress daili yo...
# 10290    healthnew children teen anxieti depress http /...
# 10291    http //ift.tt/2cx0pdnâ children teen anxieti d...
# 10292    mikestuchbery_ http //m.youtube.com/watch feat...
# 10293    africa tech n't matter live gender old areâs...
# 10294                   fuck depress honestli kill alreadi
# 10295    love lauren much emoji loudli cri face emoji l...
# 10296                                         fvck depress
# 10297    suffer chronic depress http //vine.co/v/iu3l2l...
# 10298    guess make sacrific want achiev dream famili s...
# 10299    engag physic activ decreas peopl chanc develop...
# 10300                                   depress alway darl
# 10301    suffer depress thank guy help realli love guy ...
# 10302    one children teen anxieti depress http //ift.t...
# 10303    go see hayleykiyoko next week chicago excit de...
# 10304    reagan bush trump gop use maga slogan rob trea...
# 10305    depress could improv vitamin defici treatment ...
# 10306    actor symptom adult depress nake gteen porn bl...
# 10307    gaindaswami kanatungaa being_humor theskindoct...
# 10308    mani suffer depress n't sad feel noth persist ...
# 10309      depress herbo mood done stress peopl n't deserv
# 10310    depress succumb brain make feel like 'll never...
# 10311    ketamin nasal spray show promis depress suicid...
# 10312              dont mistak bad day depress everyon 'em
# 10313
# Name: clean_message, Length: 10314, dtype: object

# %%
# implementing TF_IDF vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# tf_vectorizer = TfidfVectorizer(ngram_range=(2,2), stop_words='english')
tf_vectorizer = TfidfVectorizer(stop_words='english')

#fit and transfor,Learn the vocabulary dictionary and return term-document matrix.
X = tf_vectorizer.fit_transform(tweets.clean_message)
print(tf_vectorizer.get_feature_names())
# Out:
# ['00', '000', '00007â', '00152258', '007peter', '00am', '00pm', '02', '02am', '03', '03q2yx', '04', '042418', '0435xcwpc2', '0438138242743153', '06', '0628', '07', '07958938647', '08', '09', '09638237', '09casper', '0_0', '0ahukewirjnbe7dtaahvgkgmkhu58bx4q_auieygd', '0beck', '0bqk7k3z5i', '0i22i30j33i22i29i30l4', '0j36j4j1', '0j41j0i131j0i67j0i131i67j33i160', '0ltrdaj', '0ssnsdl0nh', '0x526vj', '10', '100', '1000', '10000', '1002', '10066808', '100âº', '101', '1011', '10156186831475782', '10156368936572238â', '10160250333315331â', '101alternativehealing', '10204373831102704â', '10216818240038376â', '10530', '106andpark', '1080', '109', '10aac3aâ', '10am', '10pm', '10th', '10x', '10yearsofenema', '10yr', '11', '110', '111448716', '112ro8', '11346264â', '113ph6', '11717343â', '1176', '11943236', '11e8', '11rep', '12', '1200', '121981_4562', '1225â', '123', '1284836754953259â', '12g9r', '12kof0', '12mp', '12pm', '12th', '12to', '13', '130', '13283521', '13cwwchdsc', '13flat', '13th', '14', '140', '1437605â', '14554550', '147048â', '149', '1492539724205071', '15', '150', '151', '152', '1523053889', '1524631761', '1524661169â', '1524670430â', '1524679856â', '1524681522â', '1524681896', '1524684188â', '1524693539â', '1524699653â', '1545', '156418â', '15aspx', '15hr', '15jyc', '15mab', '15th', '15tk11', '16', '160', '160540', '1614855991968718â', '1616018', '1635375116499792â', '165sst', '1673684982707700â', '167524017625', '1686296573', '16922738â', '16mm0h', '16qf7w', '16th', '16u6kn', '17111194', '17111194â', '175mph', '17ig4j', '17p8lj', '17th', '18', '180', '1802', '180419141530', '180424141140', '180424184119', '182', '187', '18e0c9dycr', '18mdym', '18percentgrey', '18th', '18yr', '19', '190824804', '190lb', '1912767898797971â', '1915044625â', '1920', '1929', '1930', '1932', '1938', '1943', '1975059961', '1979', '1980de88â', '1982', '1983', '1987482664609049â', '1994', '1996', '1997', '1998', '1999', '19d2z0', '19hhwz', '19hr', '19l6ok', '19n8w4', '19th', '1a4vu2', '1am', '1bq2pavwag', '1bramant', '1cappleg', '1ctzz6lâ', '1de81d6e8c71â', '1dfz30jscfdâ', '1flyharmoni', '1gs40w', '1in', '1jaredpadalecki', '1jl7a5jvd4', '1juan_contreras', '1jzsdauâ', '1lmcxcâ', '1mahf8', '1msvhk5anu', '1omarion', '1ord', '1pm', '1ppt01a1ig', '1r1z4hriw8', '1rvipupzha2d9_qakucfuyui3rn00lsh95_ir5g7ts_w', '1sj3nhhâ', '1st', '1stlady', '1stladyay', '1sweetwhirl', '1tb', '1txsage1957', '1up', '1winedud', '1xq', '1â', '20', '200', '2000', '2001', '2001273446', '2001278200', '20036559', '2005', '2006', '2007', '2008', '2009', '200902111426r', '200gb', '2010', '2012', '2013', '2014', '2015', '2016', '201605069551â', '2017', '2018', '20180425â', '201805000', '2018goal', '201b', '202', '2020', '2020scienc', '2024', '203144â', '2034029536812014â', '20353401â', '20374', '2050', '2055895251321719', '2057030744550844', '2059818', '2062778060', '206bone', '20min', '20pg', '20th', '20â', '21', '21st', '21wc2g', '22', '2207538105939980â', '221576', '2227', '226', '228', '22nd', '23', '231', '232', '236116dx', '2370', '23poetryhub', '24', '24hr', '24kgoldsher', '24th', '24ï', '25', '250', '2580179421d1â', '25april', '25mg', '25mile', '263629233337â', '266208761', '268046', '26featur', '26th', '27', '273', '28', '280zx', '28142273', '28th', '29', '2943', '29618972â', '2962', '29688389', '2aoqltfâ', '2assist', '2bm7hyfâ', '2cor', '2csuvlbâ', '2cx0pdnâ', '2d4x', '2day', '2do', '2dream', '2drxbqvâ', '2eqyvapâ', '2f04', '2f2018', '2f24', '2f39s4yâ', '2f8gna', '2fcse', '2fd6', '2fdyzlbâ', '2ff6yu7â', '2fffdmrâ', '2fhgnysâ', '2fhome', '2fhow', '2figbmqâ', '2fijovuâ', '2fnvnndâ', '2fnypost', '2forev', '2fwatch', '2fwjm70â', '2gc1hbyâ', '2gether', '2gh0h6avix', '2ghtik8â', '2gnqvbyâ', '2h58yjxâ', '2hcnuldâ', '2hhrrywâ', '2hjm8a1â', '2hjowylâ', '2hmu2alâ', '2hncpt0â', '2hnetbsâ', '2hour', '2hpa1weâ', '2hpjwv6â', '2hpshdlâ', '2hr3bhkâ', '2hrs', '2hruhbjâ', '2ht42psâ', '2htbb4râ', '2htezlbâ', '2htkjadâ', '2htoapfâ', '2htvzceâ', '2hu4kfgâ', '2humcsyâ', '2hve3dsâ', '2hwqu73â', ' ...

# %%
X.shape[0]
# Out:
# 10314

# %%
# splitting the dataset into training and testing
from sklearn.model_selection import train_test_split
y = tweets.label
X_train , X_test , y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
# getting the percentage of testing data
(X_train.shape)
print((X_test.shape[0])/((X_train.shape[0])+(X_test.shape[0]))*100)
# Out:
# 20.001939111886756

# %%
# getting the percentage of testing data

print((X_train.shape[0])/((X_train.shape[0])+(X_test.shape[0]))*100)
# Out:
# 79.99806088811324

# %%
#implementing the Naive Bayes classifier

from sklearn import naive_bayes
from sklearn.metrics import accuracy_score

# fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(X_train,y_train)
# predict the labels on validation dataset
predictions_NB = Naive.predict(X_test)
# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, y_test)*100)
# Out:
# Naive Bayes Accuracy Score ->  92.72903538536113

# %%
#classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

target_names = ['not depressed', 'depressed']

print("Classification report:")
print(classification_report(y_test, predictions_NB, target_names=target_names))

print("Confusion Matrix:")
cm = confusion_matrix(y_test, predictions_NB)
print(cm)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
# not depressed       0.92      1.00      0.96      1614
#     depressed       0.99      0.67      0.80       449
#
#     micro avg       0.93      0.93      0.93      2063
#     macro avg       0.95      0.83      0.88      2063
#  weighted avg       0.93      0.93      0.92      2063
#
# Confusion Matrix:
# [[1612    2]
#  [ 148  301]]

# %%
#plotting the confusion matrix
import seaborn as sns

# Create labels 
labels = ["Not depressed" if label == 0 else "Depressed" for label in tweets.label.unique()]

sns.set(font_scale=1.4) # for font size 
df_cm = pd.DataFrame(cm, index = [i for i in labels], 
                    columns = [i for i in labels])

plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=True, cmap="Blues", fmt='g')

# %%
#implementing the SVM classifier
from sklearn import svm

# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_train, y_train)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(X_test)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, y_test)*100)
# Out:
# SVM Accuracy Score ->  99.41832283082888

# %%
#classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

target_names = ['not depressed', 'depressed']

print("Classification report:")
print(classification_report(y_test, predictions_SVM, target_names=target_names))

print("Confusion Matrix:")
cm = confusion_matrix(y_test, predictions_SVM)
print(cm)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
# not depressed       0.99      1.00      1.00      1614
#     depressed       1.00      0.98      0.99       449
#
#     micro avg       0.99      0.99      0.99      2063
#     macro avg       1.00      0.99      0.99      2063
#  weighted avg       0.99      0.99      0.99      2063
#
# Confusion Matrix:
# [[1613    1]
#  [  11  438]]

# %%
#plotting the confusion matrix
import seaborn as sns

# Create labels 
labels = ["Not depressed" if label == 0 else "Depressed" for label in tweets.label.unique()]

sns.set(font_scale=1.4) # for font size 
df_cm = pd.DataFrame(cm, index = [i for i in labels], 
                    columns = [i for i in labels])

plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=True, cmap="Blues", fmt='g')

# %%
#implementing the Decision Tree classifier

from sklearn import tree
DT = tree.DecisionTreeClassifier()
DT = DT.fit(X_train, y_train)
predictions_DT = DT.predict(X_test)
predictions_DT
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Use accuracy_score function to get the accuracy
print("Decision Tree Accuracy Score -> ",accuracy_score(predictions_DT, y_test)*100)
# Out:
# Decision Tree Accuracy Score ->  99.61221522055259

# %%
#classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

target_names = ['not depressed', 'depressed']

print("Classification report:")
print(classification_report(y_test, predictions_DT, target_names=target_names))

print("Confusion Matrix:")
cm = confusion_matrix(y_test, predictions_DT)
print(cm)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
# not depressed       1.00      1.00      1.00      1614
#     depressed       1.00      0.98      0.99       449
#
#     micro avg       1.00      1.00      1.00      2063
#     macro avg       1.00      0.99      0.99      2063
#  weighted avg       1.00      1.00      1.00      2063
#
# Confusion Matrix:
# [[1613    1]
#  [   7  442]]

# %%
#plotting the confusion matrix
import seaborn as sns

# Create labels 
labels = ["Not depressed" if label == 0 else "Depressed" for label in tweets.label.unique()]

sns.set(font_scale=1.4) # for font size 
df_cm = pd.DataFrame(cm, index = [i for i in labels], 
                    columns = [i for i in labels])

plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=True, cmap="Blues", fmt='g')

# %%
#testing the model
#create a function to classify the tweets using the created ML model
def classify(text, classifier):
    #clean the message using clean_message function
    cleaned_text = clean_message(text)
    #only taking transform
    text_vector = tf_vectorizer.transform([cleaned_text])
    if classifier.lower() == "naive bayes":
        prediction = Naive.predict(text_vector)
    elif classifier.lower() == "svm":
        prediction = SVM.predict(text_vector)
    elif classifier.lower() == "dt":
        prediction = DT.predict(text_vector)
    else:
        prediction = -1

    if (prediction==0):
        print("Not depressed")
    elif prediction==1:
        print("Depressed")
    else:
        print("Invalid classifier provided")

# %%
#creating word cloud for Not depressed tweets
from wordcloud import WordCloud
from nltk.corpus import stopwords
positive_words = ' '.join(list(tweets[tweets['label'] == 0]['clean_message']))
positive_wc = WordCloud(width = 512,height = 512, collocations=False, colormap="Blues").generate(positive_words)
plt.figure(figsize = (10, 8), facecolor = 'k')

plt.imshow(positive_wc)
plt.axis('off'), 
plt.tight_layout(pad = 0)
plt.show()

# %%
#creating word cloud for Depressed tweets
depressive_words = ' '.join(list(tweets[tweets['label'] == 1]['clean_message']))
depressive_wc = WordCloud(width = 512,height = 512, collocations=False, colormap="Reds").generate(depressive_words)
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(depressive_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %%
#testing with Naive Bayes

# %%
#testing the model with new tweets
classifier = "Naive Bayes"
tweet = "i feel full of hope and happiness"
classify(tweet, classifier)
# Out:
# Not depressed

# %%
classifier = "Naive Bayes"
tweet = 'I feel good today. I have a lot of hope'
classify(tweet, classifier)
# Out:
# Not depressed

# %%
classifier = "Naive Bayes"
tweet = "I have depressed. I don't wanna talk to anyone. Don't want to step out. I want to be left alone" 
classify(tweet, classifier)
# Out:
# Not depressed

# %%
classifier = "Naive Bayes"
tweet = "I have anxiety issues and I don't feel good. "
classify(tweet, classifier)
# Out:
# Depressed

# %%
# testing with SVM

# %%
#testing the model with new tweets
classifier = "SVM"
tweet = "i feel full of hope and happiness"
classify(tweet, classifier)
# Out:
# Not depressed

# %%
classifier = "SVM"
tweet = 'I feel good today. I have a lot of hope'
classify(tweet, classifier)
# Out:
# Not depressed

# %%
classifier = "SVM"
tweet = "I have depressed. I don't wanna talk to anyone. Don't want to step out. I want to be left alone" 
classify(tweet, classifier)
# Out:
# Depressed

# %%
classifier = "SVM"
tweet = "I have anxiety issues and I don't feel good. "
classify(tweet, classifier)
# Out:
# Depressed

# %%
# testing with Decision Tree

# %%
#testing the model with new tweets
classifier = "DT"
tweet = "i feel full of hope and happiness"
classify(tweet, classifier)
# Out:
# Not depressed

# %%
classifier = "DT"
tweet = 'I feel good today. I have a lot of hope'
classify(tweet, classifier)
# Out:
# Not depressed

# %%
classifier = "DT"
tweet = "I have depressed. I don't wanna talk to anyone. Don't want to step out. I want to be left alone" 
classify(tweet, classifier)
# Out:
# Depressed

# %%
classifier = "DT"
tweet = "I have anxiety issues and I don't feel good. "
classify(tweet, classifier)
# Out:
# Depressed
